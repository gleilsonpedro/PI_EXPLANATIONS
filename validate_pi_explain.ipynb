# %%
import joblib
import numpy as np
import pandas as pd
from copy import deepcopy

# Carregar os artefatos salvos do main.py
modelo, X_test, explicacoes, features_usadas_lista, X_train, y_test, class_names = joblib.load('artefatos_para_teste_pi.pkl')

#modelo, X_test, explicacoes, features_usadas_lista, X_train = joblib.load('artefatos_para_teste_pi.pkl')
y_test = modelo.predict(X_test)  # Isso vai gerar as classes preditas
#class_names = ['Classe 0', 'Classe 1']


# Função para perturbar as features que não estão na explicação
def perturbar_instancia(instancia, features_a_manter, X_train):
    perturbada = instancia.copy()
    for f in instancia.index:
        if f not in features_a_manter:
            # Sorteia um valor realista da feature, com base nos dados de treino
            perturbada[f] = np.random.choice(X_train[f])
    return perturbada

# Função para validar a robustez das PI-explicações
def testar_robustez_pi(modelo, X_test, explicacoes, features_usadas_lista, X_train):
    total = 0
    mantidas = 0
    mudaram = []

    for idx, (inst_idx, instancia) in enumerate(X_test.iterrows()):
        features_usadas = features_usadas_lista[idx]
        pred_original = modelo.predict(instancia.to_frame().T)

        perturbada = perturbar_instancia(instancia, features_usadas, X_train)
        pred_perturbada = modelo.predict(instancia.to_frame().T)

        total += 1
        if pred_perturbada == pred_original:
            mantidas += 1
        else:
            mudaram.append(idx)
            print(f"Instância {idx}: Predição mudou após perturbação → {pred_original} ➜ {pred_perturbada}")

    print(f"\n Robustez geral: {mantidas}/{total} ({(mantidas / total)*100:.2f}%) instâncias mantiveram a predição.")
    if mudaram:
        print(f"\nInstâncias que falharam no teste de robustez: {mudaram}")

#  CHAME A FUNÇÃO AQUI:
testar_robustez_pi(modelo, X_test, explicacoes, features_usadas_lista, X_train)
# Out:
#  Robustez geral: 20/20 (100.00%) instâncias mantiveram a predição.

# %%
def testar_robustez_visual(modelo, X_test, y_test, explicacoes, features_usadas_lista, X_train, class_names):
    for idx, (inst_idx, original) in enumerate(X_test.iterrows()):
        features_usadas = features_usadas_lista[idx]
        real_class = y_test[idx]
        pred_original = modelo.predict(original.to_frame().T)[0]

        perturbada = original.copy()
        diffs = {}
        for f in original.index:
            if f not in features_usadas:
                novo_valor = np.random.choice(X_train[f])
                if novo_valor != original[f]:
                    diffs[f] = (original[f], novo_valor)
                perturbada[f] = novo_valor

        pred_perturbada = modelo.predict(perturbada.to_frame().T)[0]
        status = "✅" if pred_perturbada == pred_original else "❌"

        print(f"\n📌 Instância {idx} | Real: {class_names[real_class]} | Predita: {class_names[pred_original]}")
        print(f"🔍 PI-explicação (features essenciais):")
        if features_usadas:
            for f in features_usadas:
                print(f"  - {f}: {original[f]:.3f}")
        else:
            print("  - Nenhuma")

        if diffs:
            print(f"\n🎲 Perturbações aplicadas nas outras features:")
            for f, (antes, depois) in diffs.items():
                print(f"  - {f}: {antes:.3f} → {depois:.3f}")
        else:
            print("\n🎲 Nenhuma feature foi perturbada.")

        print(f"\n🔄 Predição após perturbação: {class_names[pred_perturbada]} {status}")
        print("-"*60)

# %%
testar_robustez_visual(modelo, X_test, y_test, explicacoes, features_usadas_lista, X_train, class_names)
# Out:
# 📌 Instância 0 | Real: virginica | Predita: virginica
# 🔍 PI-explicação (features essenciais):
#   - petal length (cm): 5.100
#   - sepal width (cm): 2.800
#   - sepal length (cm): 6.300
#   - petal width (cm): 1.500
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: virginica ✅
# ------------------------------------------------------------
#
# 📌 Instância 1 | Real: virginica | Predita: virginica
# 🔍 PI-explicação (features essenciais):
#   - petal length (cm): 5.600
#   - sepal width (cm): 2.900
#
# 🎲 Perturbações aplicadas nas outras features:
#   - sepal length (cm): 6.300 → 6.700
#   - petal width (cm): 1.800 → 1.900
#
# 🔄 Predição após perturbação: virginica ✅
# ------------------------------------------------------------
#
# 📌 Instância 2 | Real: virginica | Predita: virginica
# 🔍 PI-explicação (features essenciais):
#   - petal length (cm): 5.700
#   - sepal width (cm): 3.200
#
# 🎲 Perturbações aplicadas nas outras features:
#   - sepal length (cm): 6.900 → 5.100
#   - petal width (cm): 2.300 → 1.800
#
# 🔄 Predição após perturbação: virginica ✅
# ------------------------------------------------------------
#
# 📌 Instância 3 | Real: setosa | Predita: setosa
# 🔍 PI-explicação (features essenciais):
#   - sepal width (cm): 3.000
#   - petal length (cm): 1.400
#
# 🎲 Perturbações aplicadas nas outras features:
#   - sepal length (cm): 4.800 → 5.100
#   - petal width (cm): 0.300 → 2.000
#
# 🔄 Predição após perturbação: setosa ✅
# ------------------------------------------------------------
#
# 📌 Instância 4 | Real: setosa | Predita: setosa
# 🔍 PI-explicação (features essenciais):
#   - petal length (cm): 1.900
#   - sepal width (cm): 3.800
#
# 🎲 Perturbações aplicadas nas outras features:
#   - sepal length (cm): 5.100 → 6.000
#   - petal width (cm): 0.400 → 2.300
#
# 🔄 Predição após perturbação: setosa ✅
# ------------------------------------------------------------
#
# 📌 Instância 5 | Real: setosa | Predita: setosa
# 🔍 PI-explicação (features essenciais):
#   - sepal width (cm): 3.400
#   - petal length (cm): 1.500
#
# 🎲 Perturbações aplicadas nas outras features:
#   - sepal length (cm): 5.100 → 7.900
#   - petal width (cm): 0.200 → 0.300
#
# 🔄 Predição após perturbação: setosa ✅
# ------------------------------------------------------------
#
# 📌 Instância 6 | Real: setosa | Predita: setosa
# 🔍 PI-explicação (features essenciais):
#   - sepal width (cm): 3.600
#
# 🎲 Perturbações aplicadas nas outras features:
#   - sepal length (cm): 4.600 → 6.400
#   - petal length (cm): 1.000 → 1.900
#   - petal width (cm): 0.200 → 2.000
#
# 🔄 Predição após perturbação: setosa ✅
# ------------------------------------------------------------
#
# 📌 Instância 7 | Real: virginica | Predita: virginica
# 🔍 PI-explicação (features essenciais):
#   - petal length (cm): 6.100
#   - sepal width (cm): 2.800
#
# 🎲 Perturbações aplicadas nas outras features:
#   - sepal length (cm): 7.400 → 4.700
#   - petal width (cm): 1.900 → 0.200
#
# 🔄 Predição após perturbação: virginica ✅
# ------------------------------------------------------------
#
# 📌 Instância 8 | Real: setosa | Predita: setosa
# 🔍 PI-explicação (features essenciais):
#   - sepal width (cm): 3.700
#   - petal length (cm): 1.500
#
# 🎲 Perturbações aplicadas nas outras features:
#   - sepal length (cm): 5.400 → 6.500
#   - petal width (cm): 0.200 → 1.800
#
# 🔄 Predição após perturbação: setosa ✅
# ------------------------------------------------------------
#
# 📌 Instância 9 | Real: setosa | Predita: setosa
# 🔍 PI-explicação (features essenciais):
#   - sepal width (cm): 3.500
#   - petal length (cm): 1.400
#   - sepal length (cm): 5.100
#   - petal width (cm): 0.200
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: setosa ✅
# ------------------------------------------------------------
#
# 📌 Instância 10 | Real: setosa | Predita: setosa
# 🔍 PI-explicação (features essenciais):
#   - petal length (cm): 1.700
#   - sepal width (cm): 3.800
#   - sepal length (cm): 5.700
#   - petal width (cm): 0.300
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: setosa ✅
# ------------------------------------------------------------
#
# 📌 Instância 11 | Real: setosa | Predita: setosa
# 🔍 PI-explicação (features essenciais):
#   - sepal width (cm): 3.100
#   - petal length (cm): 1.600
#
# 🎲 Perturbações aplicadas nas outras features:
#   - sepal length (cm): 4.800 → 7.200
#   - petal width (cm): 0.200 → 2.500
#
# 🔄 Predição após perturbação: setosa ✅
# ------------------------------------------------------------
#
# 📌 Instância 12 | Real: virginica | Predita: virginica
# 🔍 PI-explicação (features essenciais):
#   - petal length (cm): 4.900
#   - sepal width (cm): 2.700
#
# 🎲 Perturbações aplicadas nas outras features:
#   - sepal length (cm): 6.300 → 5.400
#   - petal width (cm): 1.800 → 2.200
#
# 🔄 Predição após perturbação: virginica ✅
# ------------------------------------------------------------
#
# 📌 Instância 13 | Real: setosa | Predita: setosa
# 🔍 PI-explicação (features essenciais):
#   - petal length (cm): 1.400
#   - sepal width (cm): 4.200
#   - sepal length (cm): 5.500
#   - petal width (cm): 0.200
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: setosa ✅
# ------------------------------------------------------------
#
# 📌 Instância 14 | Real: virginica | Predita: virginica
# 🔍 PI-explicação (features essenciais):
#   - petal length (cm): 5.600
#   - sepal width (cm): 3.100
#
# 🎲 Perturbações aplicadas nas outras features:
#   - sepal length (cm): 6.700 → 6.100
#   - petal width (cm): 2.400 → 0.400
#
# 🔄 Predição após perturbação: virginica ✅
# ------------------------------------------------------------
#
# 📌 Instância 15 | Real: setosa | Predita: setosa
# 🔍 PI-explicação (features essenciais):
#   - sepal width (cm): 3.600
#   - petal length (cm): 1.400
#   - sepal length (cm): 5.000
#   - petal width (cm): 0.200
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: setosa ✅
# ------------------------------------------------------------
#
# 📌 Instância 16 | Real: virginica | Predita: virginica
# 🔍 PI-explicação (features essenciais):
#   - petal length (cm): 4.800
#   - sepal width (cm): 2.800
#   - sepal length (cm): 6.200
#   - petal width (cm): 1.800
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: virginica ✅
# ------------------------------------------------------------
#
# 📌 Instância 17 | Real: virginica | Predita: virginica
# 🔍 PI-explicação (features essenciais):
#   - petal length (cm): 4.900
#   - sepal width (cm): 3.000
#
# 🎲 Perturbações aplicadas nas outras features:
#   - sepal length (cm): 6.100 → 7.400
#   - petal width (cm): 1.800 → 0.200
#
# 🔄 Predição após perturbação: virginica ✅
# ------------------------------------------------------------
#
# 📌 Instância 18 | Real: setosa | Predita: setosa
# 🔍 PI-explicação (features essenciais):
#   - sepal width (cm): 3.000
#   - petal length (cm): 1.400
#
# 🎲 Perturbações aplicadas nas outras features:
#   - sepal length (cm): 4.800 → 5.000
#   - petal width (cm): 0.100 → 0.600
#
# 🔄 Predição após perturbação: setosa ✅
# ------------------------------------------------------------
#
# 📌 Instância 19 | Real: setosa | Predita: setosa
# 🔍 PI-explicação (features essenciais):
#   - sepal width (cm): 3.400
#   - petal length (cm): 1.500
#
# 🎲 Perturbações aplicadas nas outras features:
#   - sepal length (cm): 5.400 → 4.700
#   - petal width (cm): 0.400 → 1.800
#
# 🔄 Predição após perturbação: setosa ✅
# ------------------------------------------------------------
