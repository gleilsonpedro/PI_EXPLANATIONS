# %%
import joblib
import numpy as np
import pandas as pd
from copy import deepcopy

# Carregar os artefatos salvos do main.py
modelo, X_test, explicacoes, features_usadas_lista, X_train, y_test, class_names = joblib.load('artefatos_para_teste_pi.pkl')

#modelo, X_test, explicacoes, features_usadas_lista, X_train = joblib.load('artefatos_para_teste_pi.pkl')
y_test = modelo.predict(X_test)  # Isso vai gerar as classes preditas
#class_names = ['Classe 0', 'Classe 1']


# Função para perturbar as features que não estão na explicação
def perturbar_instancia(instancia, features_a_manter, X_train):
    perturbada = instancia.copy()
    for f in instancia.index:
        if f not in features_a_manter:
            # Sorteia um valor realista da feature, com base nos dados de treino
            perturbada[f] = np.random.choice(X_train[f])
    return perturbada

# Função para validar a robustez das PI-explicações
def testar_robustez_pi(modelo, X_test, explicacoes, features_usadas_lista, X_train):
    total = 0
    mantidas = 0
    mudaram = []

    for idx, (inst_idx, instancia) in enumerate(X_test.iterrows()):
        features_usadas = features_usadas_lista[idx]
        pred_original = modelo.predict(instancia.to_frame().T)

        perturbada = perturbar_instancia(instancia, features_usadas, X_train)
        pred_perturbada = modelo.predict(instancia.to_frame().T)

        total += 1
        if pred_perturbada == pred_original:
            mantidas += 1
        else:
            mudaram.append(idx)
            print(f"Instância {idx}: Predição mudou após perturbação → {pred_original} ➜ {pred_perturbada}")

    print(f"\n Robustez geral: {mantidas}/{total} ({(mantidas / total)*100:.2f}%) instâncias mantiveram a predição.")
    if mudaram:
        print(f"\nInstâncias que falharam no teste de robustez: {mudaram}")

#  CHAME A FUNÇÃO AQUI:
testar_robustez_pi(modelo, X_test, explicacoes, features_usadas_lista, X_train)
# Out:
#  Robustez geral: 154/154 (100.00%) instâncias mantiveram a predição.

# %%
from sklearn.linear_model import LogisticRegression

print("VALIDAÇÃO DAS PI-EXPLICAÇÕES\n" + "="*40)

for i, x in enumerate(X_test):
    pi_info = pi_explanations[i]
    pi_indices = set(pi_info["feature_indices"])
    original_pred = model.predict([x])[0]

    perturbed_x = x.copy()
    perturbations = {}

    for j in range(len(x)):
        if j not in pi_indices:
            original_value = x[j]
            new_value = np.random.choice(X_train[:, j])  # você pode trocar isso por outra estratégia
            perturbed_x[j] = new_value
            perturbations[j] = (original_value, new_value)

    new_pred = model.predict([perturbed_x])[0]

    print(f"\nInstância {i} | Real: {label_names[y_test[i]]} | Predita: {label_names[original_pred]}")
    print("PI-Explicação (essenciais):")
    for j in pi_indices:
        print(f"  - {feature_names[j]} = {x[j]:.2f}")

    if perturbations:
        print("Perturbações nas outras features:")
        for j, (orig, pert) in perturbations.items():
            print(f"  - {feature_names[j]}: original = {orig:.2f} → perturbação = {pert:.2f}")
    else:
        print("Nenhuma feature foi perturbada.")

    print(f"Predição após perturbação: {label_names[new_pred]} {'✅' if new_pred == original_pred else '❌'}")

print("\n✅ Validação completa.")
# Out:
# VALIDAÇÃO DAS PI-EXPLICAÇÕES
# ========================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       3 print("VALIDAÇÃO DAS PI-EXPLICAÇÕES\n" + "="*40)
#       5 for i, x in enumerate(X_test):
# ----> 6     pi_info = pi_explanations[i]
#       7     pi_indices = set(pi_info["feature_indices"])
#       8     original_pred = model.predict([x])[0]
#
# NameError: name 'pi_explanations' is not defined

# %%
def testar_robustez_visual(modelo, X_test, y_test, explicacoes, features_usadas_lista, X_train, class_names):
    for idx, (inst_idx, original) in enumerate(X_test.iterrows()):
        features_usadas = features_usadas_lista[idx]
        real_class = y_test[idx]
        pred_original = modelo.predict(original.to_frame().T)[0]

        perturbada = original.copy()
        diffs = {}
        for f in original.index:
            if f not in features_usadas:
                novo_valor = np.random.choice(X_train[f])
                if novo_valor != original[f]:
                    diffs[f] = (original[f], novo_valor)
                perturbada[f] = novo_valor

        pred_perturbada = modelo.predict(perturbada.to_frame().T)[0]
        status = "✅" if pred_perturbada == pred_original else "❌"

        print(f"\n📌 Instância {idx} | Real: {class_names[real_class]} | Predita: {class_names[pred_original]}")
        print(f"🔍 PI-explicação (features essenciais):")
        if features_usadas:
            for f in features_usadas:
                print(f"  - {f}: {original[f]:.3f}")
        else:
            print("  - Nenhuma")

        if diffs:
            print(f"\n🎲 Perturbações aplicadas nas outras features:")
            for f, (antes, depois) in diffs.items():
                print(f"  - {f}: {antes:.3f} → {depois:.3f}")
        else:
            print("\n🎲 Nenhuma feature foi perturbada.")

        print(f"\n🔄 Predição após perturbação: {class_names[pred_perturbada]} {status}")
        print("-"*60)

# %%
testar_robustez_visual(modelo, X_test, y_test, explicacoes, features_usadas_lista, X_train, class_names)
# Out:
# 📌 Instância 0 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 98.000
#   - imc: 34.000
#   - pressao_sangue: 58.000
#   - idade: 43.000
#   - diabetes_pedigree: 0.430
#   - num_gravidezes: 6.000
#   - insulina: 190.000
#   - espessura_pele: 33.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 1 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 112.000
#   - imc: 35.700
#   - idade: 21.000
#   - pressao_sangue: 75.000
#   - diabetes_pedigree: 0.148
#   - num_gravidezes: 2.000
#   - espessura_pele: 32.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 2 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 108.000
#   - imc: 30.800
#   - idade: 21.000
#   - pressao_sangue: 64.000
#   - num_gravidezes: 2.000
#   - diabetes_pedigree: 0.158
#   - espessura_pele: 0.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 3 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 24.600
#   - glicose: 107.000
#   - pressao_sangue: 80.000
#   - idade: 34.000
#   - diabetes_pedigree: 0.856
#   - num_gravidezes: 8.000
#   - espessura_pele: 0.000
#
# 🎲 Perturbações aplicadas nas outras features:
#   - insulina: 0.000 → 79.000
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 4 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 29.900
#   - pressao_sangue: 90.000
#   - glicose: 136.000
#   - diabetes_pedigree: 0.210
#   - idade: 50.000
#   - num_gravidezes: 7.000
#   - espessura_pele: 0.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 5 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 103.000
#   - imc: 37.700
#   - pressao_sangue: 72.000
#   - diabetes_pedigree: 0.324
#   - num_gravidezes: 6.000
#   - idade: 55.000
#   - insulina: 190.000
#   - espessura_pele: 32.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 6 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 71.000
#   - imc: 20.400
#   - idade: 22.000
#   - num_gravidezes: 1.000
#   - diabetes_pedigree: 0.323
#   - pressao_sangue: 48.000
#   - espessura_pele: 18.000
#   - insulina: 76.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 7 | Real: Diabético | Predita: Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 33.800
#   - glicose: 117.000
#   - num_gravidezes: 0.000
#   - idade: 44.000
#   - diabetes_pedigree: 0.932
#   - espessura_pele: 0.000
#   - pressao_sangue: 0.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 8 | Real: Diabético | Predita: Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc:
| Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 38.200
#   - pressao_sangue: 76.000
#   - glicose: 146.000
#   - idade: 29.000
#   - num_gravidezes: 2.000
#   - diabetes_pedigree: 0.329
#   - insulina: 194.000
#   - espessura_pele: 35.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 104 | Real: Diabético | Predita: Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 32.900
#   - pressao_sangue: 78.000
#   - idade: 31.000
#   - glicose: 158.000
#   - num_gravidezes: 4.000
#   - diabetes_pedigree: 0.803
#   - espessura_pele: 0.000
#
# 🎲 Perturbações aplicadas nas outras features:
#   - insulina: 0.000 → 50.000
#
# 🔄 Predição após perturbação: Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 105 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 112.000
#   - imc: 38.400
#   - pressao_sangue: 86.000
#   - idade: 28.000
#   - num_gravidezes: 2.000
#   - diabetes_pedigree: 0.246
#   - insulina: 160.000
#   - espessura_pele: 42.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 106 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 25.400
#   - glicose: 141.000
#   - idade: 24.000
#   - pressao_sangue: 58.000
#   - num_gravidezes: 2.000
#   - diabetes_pedigree: 0.699
#   - insulina: 128.000
#   - espessura_pele: 34.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 107 | Real: Diabético | Predita: Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 33.800
#   - pressao_sangue: 78.000
#   - idade: 31.000
#   - num_gravidezes: 3.000
#   - glicose: 173.000
#   - diabetes_pedigree: 0.970
#   - insulina: 185.000
#   - espessura_pele: 39.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 108 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 80.000
#   - imc: 34.200
#   - pressao_sangue: 82.000
#   - idade: 27.000
#   - num_gravidezes: 3.000
#   - diabetes_pedigree: 1.292
#   - espessura_pele: 31.000
#   - insulina: 70.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 109 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 109.000
#   - imc: 35.900
#   - pressao_sangue: 80.000
#   - idade: 43.000
#   - num_gravidezes: 7.000
#   - diabetes_pedigree: 1.127
#   - espessura_pele: 31.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 110 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 97.000
#   - imc: 28.200
#   - idade: 22.000
#   - pressao_sangue: 60.000
#   - diabetes_pedigree: 0.443
#   - num_gravidezes: 4.000
#   - espessura_pele: 23.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 111 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 22.900
#   - pressao_sangue: 88.000
#   - idade: 22.000
#   - num_gravidezes: 2.000
#   - diabetes_pedigree: 0.326
#   - glicose: 175.000
#   - espessura_pele: 0.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 112 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 0.000
#   - glicose: 105.000
#   - idade: 24.000
#   - diabetes_pedigree: 0.305
#   - num_gravidezes: 7.000
#   - espessura_pele: 0.000
#
# 🎲 Perturbações aplicadas nas outras features:
#   - pressao_sangue: 0.000 → 76.000
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# ...
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 117 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 110.000
#   - imc: 31.900
#   - idade: 29.000
#   - pressao_sangue: 66.000
#   - num_gravidezes: 4.000
#   - diabetes_pedigree: 0.471
#   - espessura_pele: 0.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 118 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 91.000
#   - imc: 27.300
#   - idade: 22.000
#   - pressao_sangue: 62.000
#   - num_gravidezes: 2.000
#   - diabetes_pedigree: 0.525
#   - espessura_pele: 0.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 119 | Real: Diabético | Predita: Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 115.000
#   - imc: 35.300
#   - idade: 29.000
#   - diabetes_pedigree: 0.134
#   - num_gravidezes: 10.000
#   - espessura_pele: 0.000
#
# 🎲 Perturbações aplicadas nas outras features:
#   - pressao_sangue: 0.000 → 94.000
#   - insulina: 0.000 → 328.000
#
# 🔄 Predição após perturbação: Não Diabético ❌
# ------------------------------------------------------------
#
# 📌 Instância 120 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 24.300
#   - glicose: 105.000
#   - idade: 21.000
#   - num_gravidezes: 1.000
#   - pressao_sangue: 58.000
#   - diabetes_pedigree: 0.187
#   - espessura_pele: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 121 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 100.000
#   - imc: 40.500
#   - idade: 25.000
#   - pressao_sangue: 70.000
#   - num_gravidezes: 2.000
#   - diabetes_pedigree: 0.677
#   - espessura_pele: 52.000
#   - insulina: 57.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 122 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 29.000
#   - glicose: 119.000
#   - pressao_sangue: 80.000
#   - idade: 29.000
#   - diabetes_pedigree: 0.263
#   - num_gravidezes: 9.000
#   - espessura_pele: 35.000
#
# 🎲 Perturbações aplicadas nas outras features:
#   - insulina: 0.000 → 53.000
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 123 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 90.000
#   - imc: 25.100
#   - idade: 25.000
#   - pressao_sangue: 62.000
#   - num_gravidezes: 1.000
#   - diabetes_pedigree: 1.268
#   - espessura_pele: 18.000
#   - insulina: 59.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 124 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 26.100
#   - idade: 22.000
#   - glicose: 151.000
#   - pressao_sangue: 60.000
#   - num_gravidezes: 1.000
#   - diabetes_pedigree: 0.179
#   - espessura_pele: 0.000
#
# 🎲 Perturbações aplicadas nas outras features:
#   - insulina: 0.000 → 127.000
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 125 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 101.000
#   - imc: 32.900
#   - pressao_sangue: 76.000
#   - diabetes_pedigree: 0.171
#   - num_gravidezes: 10.000
#   - idade: 63.000
#   - insulina: 180.000
#   - espessura_pele: 48.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 126 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 0.000
#   - glicose: 115.000
#   - idade: 30.000
#   - diabetes_pedigree: 0.261
#   - num_gravidezes: 10.000
#   - espessura_pele: 0.000
#
# 🎲 Perturbações aplicadas nas outras features:
#   - pressao_sangue: 0.000 → 78.000
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 127 | Real: Diabético | Predita: Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 33.300
#   - pressao_sangue: 76.000
#   - glicose: 155.000
#   - idade: 51.000
#   - diabetes_pedigree: 1.353
#   - num_gravidezes: 11.000
#   - insulina: 150.000
#   - espessura_pele: 28.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 128 | Real: Diabético | Predita: Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 135.000
#   - idade: 40.000
#   - imc: 52.300
#   - diabetes_pedigree: 0.578
#   - num_gravidezes: 11.000
#   - espessura_pele: 0.000
#
# 🎲 Perturbações aplicadas nas outras features:
#   - insulina: 0.000 → 46.000
#
# 🔄 Predição após perturbação: Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 129 | Real: Diabético | Predita: Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 28.500
#   - pressao_sangue: 110.000
#   - idade: 37.000
#   - num_gravidezes: 4.000
#   - diabetes_pedigree: 0.680
#   - glicose: 189.000
#   - espessura_pele: 31.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 130 | Real: Diabético | Predita: Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 23.300
#   - idade: 32.000
#   - pressao_sangue: 64.000
#   - diabetes_pedigree: 0.672
#   - num_gravidezes: 8.000
#   - glicose: 183.000
#   - espessura_pele: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 131 | Real: Diabético | Predita: Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 41.800
#   - pressao_sangue: 70.000
#   - glicose: 151.000
#   - idade: 38.000
#   - diabetes_pedigree: 0.742
#   - num_gravidezes: 12.000
#   - insulina: 271.000
#   - espessura_pele: 40.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 132 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 25.400
#   - glicose: 109.000
#   - idade: 21.000
#   - pressao_sangue: 60.000
#   - num_gravidezes: 1.000
#   - diabetes_pedigree: 0.947
#   - insulina: 182.000
#   - espessura_pele: 8.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 133 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 28.300
#   - glicose: 136.000
#   - pressao_sangue: 84.000
#   - diabetes_pedigree: 0.260
#   - idade: 42.000
#   - num_gravidezes: 11.000
#   - insulina: 130.000
#   - espessura_pele: 35.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 134 | Real: Diabético | Predita: Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 40.000
#   - pressao_sangue: 78.000
#   - idade: 22.000
#   - num_gravidezes: 1.000
#   - diabetes_pedigree: 1.258
#   - glicose: 181.000
#   - insulina: 293.000
#   - espessura_pele: 42.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 135 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 102.000
#   - imc: 29.500
#   - pressao_sangue: 74.000
#   - idade: 32.000
#   - diabetes_pedigree: 0.121
#   - num_gravidezes: 3.000
#   - espessura_pele: 0.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 136 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 28.400
#   - glicose: 120.000
#   - pressao_sangue: 86.000
#   - idade: 22.000
#   - diabetes_pedigree: 0.259
#   - num_gravidezes: 8.000
#   - espessura_pele: 0.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 137 | Real: Diabético | Predita: Diabético
# 🔍 PI-explicação (features essenciais):
#   - pressao_sangue: 114.000
#   - imc: 42.300
#   - glicose: 158.000
#   - diabetes_pedigree: 0.257
#   - idade: 44.000
#   - num_gravidezes: 13.000
#   - espessura_pele: 0.000
#
# 🎲 Perturbações aplicadas nas outras features:
#   - insulina: 0.000 → 175.000
#
# 🔄 Predição após perturbação: Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 138 | Real: Diabético | Predita: Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 35.200
#   - pressao_sangue: 78.000
#   - glicose: 150.000
#   - diabetes_pedigree: 0.692
#   - num_gravidezes: 7.000
#   - idade: 54.000
#   - espessura_pele: 29.000
#   - insulina: 126.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 139 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 68.000
#   - imc: 20.100
#   - idade: 23.000
#   - pressao_sangue: 62.000
#   - num_gravidezes: 2.000
#   - diabetes_pedigree: 0.257
#   - espessura_pele: 13.000
#   - insulina: 15.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 140 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 25.000
#   - glicose: 112.000
#   - idade: 24.000
#   - pressao_sangue: 66.000
#   - num_gravidezes: 2.000
#   - diabetes_pedigree: 0.307
#   - espessura_pele: 22.000
#
# 🎲 Perturbações aplicadas nas outras features:
#   - insulina: 0.000 → 140.000
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 141 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 90.000
#   - imc: 23.500
#   - idade: 25.000
#   - pressao_sangue: 60.000
#   - num_gravidezes: 2.000
#   - diabetes_pedigree: 0.191
#   - espessura_pele: 0.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 142 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 25.600
#   - glicose: 139.000
#   - pressao_sangue: 75.000
#   - idade: 29.000
#   - num_gravidezes: 2.000
#   - diabetes_pedigree: 0.167
#   - espessura_pele: 0.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 143 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 40.700
#   - glicose: 139.000
#   - idade: 21.000
#   - pressao_sangue: 62.000
#   - num_gravidezes: 1.000
#   - diabetes_pedigree: 0.536
#   - insulina: 480.000
#   - espessura_pele: 41.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 144 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 93.000
#   - imc: 35.300
#   - idade: 25.000
#   - num_gravidezes: 0.000
#   - pressao_sangue: 60.000
#   - diabetes_pedigree: 0.263
#   - espessura_pele: 0.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 145 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 84.000
#   - imc: 38.300
#   - pressao_sangue: 74.000
#   - idade: 39.000
#   - diabetes_pedigree: 0.457
#   - num_gravidezes: 8.000
#   - espessura_pele: 31.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 146 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 85.000
#   - imc: 29.000
#   - pressao_sangue: 74.000
#   - idade: 32.000
#   - num_gravidezes: 5.000
#   - diabetes_pedigree: 1.224
#   - espessura_pele: 22.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 147 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 73.000
#   - imc: 23.000
#   - idade: 21.000
#   - num_gravidezes: 1.000
#   - diabetes_pedigree: 0.248
#   - pressao_sangue: 50.000
#   - espessura_pele: 10.000
#
# 🎲 Perturbações aplicadas nas outras features:
#   - insulina: 0.000 → 105.000
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 148 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 112.000
#   - imc: 39.400
#   - pressao_sangue: 78.000
#   - idade: 38.000
#   - diabetes_pedigree: 0.236
#   - num_gravidezes: 4.000
#   - espessura_pele: 40.000
#
# 🎲 Perturbações aplicadas nas outras features:
#   - insulina: 0.000 → 330.000
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 149 | Real: Diabético | Predita: Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 30.400
#   - pressao_sangue: 88.000
#   - diabetes_pedigree: 0.302
#   - glicose: 165.000
#   - idade: 49.000
#   - num_gravidezes: 9.000
#   - espessura_pele: 0.000
#   - insulina: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 150 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 77.000
#   - imc: 33.300
#   - idade: 24.000
#   - num_gravidezes: 1.000
#   - pressao_sangue: 56.000
#   - diabetes_pedigree: 1.251
#   - espessura_pele: 30.000
#   - insulina: 56.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 151 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 95.000
#   - imc: 36.800
#   - pressao_sangue: 72.000
#   - diabetes_pedigree: 0.485
#   - num_gravidezes: 8.000
#   - idade: 57.000
#   - espessura_pele: 0.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 152 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - imc: 28.000
#   - glicose: 146.000
#   - pressao_sangue: 70.000
#   - idade: 29.000
#   - num_gravidezes: 2.000
#   - diabetes_pedigree: 0.337
#   - insulina: 360.000
#   - espessura_pele: 38.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
#
# 📌 Instância 153 | Real: Não Diabético | Predita: Não Diabético
# 🔍 PI-explicação (features essenciais):
#   - glicose: 74.000
#   - imc: 35.300
#   - pressao_sangue: 70.000
#   - idade: 39.000
#   - diabetes_pedigree: 0.705
#   - num_gravidezes: 8.000
#   - espessura_pele: 40.000
#   - insulina: 49.000
#
# 🎲 Nenhuma feature foi perturbada.
#
# 🔄 Predição após perturbação: Não Diabético ✅
# ------------------------------------------------------------
